# %% [markdown]
# ## main package download

# %%
# !pip install -U git+"https://github.com/silvestrefernandosci/The-FREUID-Challenge-2026-IJCAI-ECAI.git"
# Out:
# Processing /home/fernando/lab/packages/The-FREUID-Challenge-2026-IJCAI-ECAI
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /home/fernando/lab/.venv/lib/python3.12/site-packages (from the-freuid-challenge-2026-ijcai-ecai==0.1.0) (2.11.0)
# Requirement already satisfied: torchvision in /home/fernando/lab/.venv/lib/python3.12/site-packages (from the-freuid-challenge-2026-ijcai-ecai==0.1.0) (0.26.0)
# Requirement already satisfied: pillow in /home/fernando/lab/.venv/lib/python3.12/site-packages (from the-freuid-challenge-2026-ijcai-ecai==0.1.0) (12.2.0)
# Requirement already satisfied: numpy in /home/fernando/lab/.venv/lib/python3.12/site-packages (from the-freuid-challenge-2026-ijcai-ecai==0.1.0) (2.4.4)
# Requirement already satisfied: filelock in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (2026.3.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fernando/lab/.venv/lib/python3.12/site-packages (from jinja2->torch->the-freuid-challenge-2026-ijcai-ecai==0.1.0) (3.0.3)
# Building wheels for collected packages: the-freuid-challenge-2026-ijcai-ecai
#   Building wheel for the-freuid-challenge-2026-ijcai-ecai (pyproject.toml) ... done
#   Created wheel for the-freuid-challenge-2026-ijcai-ecai: filename=the_freuid_challenge_2026_ijcai_ecai-0.1.0-py3-none-any.whl size=8202 sha256=9af00bc6f7400ed4d6e6222dd3c4d6ba234bde6263d5ac68874955b6366397e8
#   Stored in directory: /home/fernando/.cache/pip/wheels/56/6d/0b/34430422707ae9e113a423849dd0b001a5e67849d43a92532e
# Successfully built the-freuid-challenge-2026-ijcai-ecai
# Installing collected packages: the-freuid-challenge-2026-ijcai-ecai
#   Attempting uninstall: the-freuid-challenge-2026-ijcai-ecai
#     Found existing installation: the-freuid-challenge-2026-ijcai-ecai 0.1.0
#     Uninstalling the-freuid-challenge-2026-ijcai-ecai-0.1.0:
#       Successfully uninstalled the-freuid-challenge-2026-ijcai-ecai-0.1.0
# Successfully installed the-freuid-challenge-2026-ijcai-ecai-0.1.0

# %%
import torch
from fraud_model import Workflow, RestNetClassifier

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = RestNetClassifier()
model = model.to(device)

# %%
workflow = Workflow(
    'the-freuid-challenge-2026-ijcai-ecai',
    dataset_size=0.08
)

# %%
model = workflow.train(model)
# Out:
# Start model train
# Epoch [1/10]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model = workflow.train(model)
#
# File ~/lab/.venv/lib/python3.12/site-packages/fraud_model/workflow.py:114, in Workflow.train(self, model)
#     111 outputs = model(images)
#     112 loss = criterion(outputs, labels)
# --> 114 loss.backward()
#     115 optimizer.step()
#     117 train_loss += loss.item()
#
# File ~/lab/.venv/lib/python3.12/site-packages/torch/_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File ~/lab/.venv/lib/python3.12/site-packages/torch/autograd/__init__.py:381, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     376     retain_graph = create_graph
#     378 # The reason we repeat the same comment below is that
#     379 # some Python versions print out the first line of a multi-line function
#     380 # calls in the traceback and some print out the last line
# --> 381 _engine_run_backward(
#     382     tensors,
#     383     grad_tensors_,
#     384     retain_graph,
#     385     create_graph,
#     386     inputs_tuple,
#     387     allow_unreachable=True,
#     388     accumulate_grad=True,
#     389 )
#
# File ~/lab/.venv/lib/python3.12/site-packages/torch/autograd/graph.py:869, in _engine_run_backward(t_outputs, *args, **kwargs)
#     867     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     868 try:
# --> 869     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     870         t_outputs, *args, **kwargs
#     871     )  # Calls into the C++ engine to run the backward pass
#     872 finally:
#     873     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
workflow.save(model, 'model_freuid_resnet18.pth')

# %%
workflow.submition('submition.csv')

# %%
import pandas as pd
df = pd.read_csv('the-freuid-challenge-2026-ijcai-ecai/train_labels.csv')

int(df.shape[0] * 0.008)
# Out:
# 554
